# %% [markdown]
# ##### CREATE HISTOGRAMS
# Histogram is a graph that shows the number of observations within every interval.
# It shows frequency distributions.
# Use the `hist()` function to create a histogram.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
